# %%
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
data=pd.read_csv('/content/i5dem.csv')

# %%
data
# Out:
#                    product;month_cons;inventory;rec_qte
# 0                            1% Milk;14.067;3.188;4.215
# 1                             1% Milk;14.067;1.691;5.03
# 2                              1% Milk;14.067;3.147;3.8
# 3                             1% Milk;14.067;3.71;3.732
# 4                            1% Milk;14.067;2.906;4.069
# ...                                                 ...
# 2700  Grilled Scallops with Lemon Butter;10.806;1.18...
# 2701  Grilled Scallops with Lemon Butter;10.806;1.18...
# 2702  Grilled Scallops with Lemon Butter;10.806;2.22...
# 2703  Grilled Scallops with Lemon Butter;10.806;3.94...
# 2704  Grilled Scallops with Lemon Butter;10.806;2.34...
#
# [2705 rows x 1 columns]

# %%
data = data["product;month_cons;inventory;rec_qte"].str.split(";", expand=True)

# Rename the columns
data.columns = ["product", "month_cons","inventory","rec_qte"]
data.to_csv('/content/modified_data.csv', index=False)

# %%
data
# Out:
#                                  product month_cons inventory rec_qte
# 0                                1% Milk     14.067     3.188   4.215
# 1                                1% Milk     14.067     1.691    5.03
# 2                                1% Milk     14.067     3.147     3.8
# 3                                1% Milk     14.067      3.71   3.732
# 4                                1% Milk     14.067     2.906   4.069
# ...                                  ...        ...       ...     ...
# 2700  Grilled Scallops with Lemon Butter     10.806     1.186   3.605
# 2701  Grilled Scallops with Lemon Butter     10.806     1.187   3.332
# 2702  Grilled Scallops with Lemon Butter     10.806     2.224   3.306
# 2703  Grilled Scallops with Lemon Butter     10.806     3.945   2.578
# 2704  Grilled Scallops with Lemon Butter     10.806     2.347   3.192
#
# [2705 rows x 4 columns]

# %%
row_1106 = data.loc[439]

# %%
row_1106
# Out:
# product       Chicken Fajitas
# month_cons             10.217
# inventory               3.863
# rec_qte                 2.586
# Name: 439, dtype: object

# %%
res=data

# %%
data.to_csv('/content/mod_data.csv', index=False)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
data["encoded_product"] = label_encoder.fit_transform(data["product"])

# %%
data
# Out:
#                                  product month_cons inventory rec_qte  \
# 0                                1% Milk     14.067     3.188   4.215
# 1                                1% Milk     14.067     1.691    5.03
# 2                                1% Milk     14.067     3.147     3.8
# 3                                1% Milk     14.067      3.71   3.732
# 4                                1% Milk     14.067     2.906   4.069
# ...                                  ...        ...       ...     ...
# 2700  Grilled Scallops with Lemon Butter     10.806     1.186   3.605
# 2701  Grilled Scallops with Lemon Butter     10.806     1.187   3.332
# 2702  Grilled Scallops with Lemon Butter     10.806     2.224   3.306
# 2703  Grilled Scallops with Lemon Butter     10.806     3.945   2.578
# 2704  Grilled Scallops with Lemon Butter     10.806     2.347   3.192
#
#       encoded_product
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 2700              201
# 2701              201
# 2702              201
# 2703              201
# 2704              201
#
# [2705 rows x 5 columns]

# %%
uni_prod = data[["product", "encoded_product"]].drop_duplicates()

# Create a dictionary mapping product names to their encoded values
product_mapping = dict(zip(uni_prod["product"], uni_prod["encoded_product"]))

# %%
df=data

# %%
#df["inventory"] = pd.to_numeric(df["inventory"], errors="coerce")

# %%
#df["inventory"]=df["inventory"].astype(float)

# %%
df["month_cons"] = pd.to_numeric(df["month_cons"], errors="coerce")
df["month_cons"]=df["month_cons"].astype(float)
df["rec_qte"] = pd.to_numeric(df["rec_qte"], errors="coerce")
df["rec_qte"]=df["rec_qte"].astype(float)

# %%
df = df.dropna()

# %%
df
# Out:
#                                  product  month_cons inventory  rec_qte  \
# 0                                1% Milk      14.067     3.188    4.215
# 1                                1% Milk      14.067     1.691    5.030
# 2                                1% Milk      14.067     3.147    3.800
# 3                                1% Milk      14.067      3.71    3.732
# 4                                1% Milk      14.067     2.906    4.069
# ...                                  ...         ...       ...      ...
# 2700  Grilled Scallops with Lemon Butter      10.806     1.186    3.605
# 2701  Grilled Scallops with Lemon Butter      10.806     1.187    3.332
# 2702  Grilled Scallops with Lemon Butter      10.806     2.224    3.306
# 2703  Grilled Scallops with Lemon Butter      10.806     3.945    2.578
# 2704  Grilled Scallops with Lemon Butter      10.806     2.347    3.192
#
#       encoded_product
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 2700              201
# 2701              201
# 2702              201
# 2703              201
# 2704              201
#
# [2705 rows x 5 columns]

# %%
df["month_cons"].astype(float)
# Out:
# 0       14.067
# 1       14.067
# 2       14.067
# 3       14.067
# 4       14.067
#          ...
# 2700    10.806
# 2701    10.806
# 2702    10.806
# 2703    10.806
# 2704    10.806
# Name: month_cons, Length: 2705, dtype: float64

# %%
df["inventory"].astype(float)
df["rec_qte"].astype(float)
# Out:
# 0       4.215
# 1       5.030
# 2       3.800
# 3       3.732
# 4       4.069
#         ...
# 2700    3.605
# 2701    3.332
# 2702    3.306
# 2703    2.578
# 2704    3.192
# Name: rec_qte, Length: 2705, dtype: float64

# %%
df = df.reset_index(drop=True)

# %%
data=df

# %%
data
# Out:
#                                  product  month_cons inventory  rec_qte  \
# 0                                1% Milk      14.067     3.188    4.215
# 1                                1% Milk      14.067     1.691    5.030
# 2                                1% Milk      14.067     3.147    3.800
# 3                                1% Milk      14.067      3.71    3.732
# 4                                1% Milk      14.067     2.906    4.069
# ...                                  ...         ...       ...      ...
# 2700  Grilled Scallops with Lemon Butter      10.806     1.186    3.605
# 2701  Grilled Scallops with Lemon Butter      10.806     1.187    3.332
# 2702  Grilled Scallops with Lemon Butter      10.806     2.224    3.306
# 2703  Grilled Scallops with Lemon Butter      10.806     3.945    2.578
# 2704  Grilled Scallops with Lemon Butter      10.806     2.347    3.192
#
#       encoded_product
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 2700              201
# 2701              201
# 2702              201
# 2703              201
# 2704              201
#
# [2705 rows x 5 columns]

# %%
df.drop("product",axis=1,inplace=True)

# %%
Y=df["rec_qte"]

# %%
Y
# Out:
# 0       4.215
# 1       5.030
# 2       3.800
# 3       3.732
# 4       4.069
#         ...
# 2700    3.605
# 2701    3.332
# 2702    3.306
# 2703    2.578
# 2704    3.192
# Name: rec_qte, Length: 2705, dtype: float64

# %%
X=df.drop("rec_qte",axis=1)

# %%
X
# Out:
#       month_cons inventory  encoded_product
# 0         14.067     3.188                0
# 1         14.067     1.691                0
# 2         14.067     3.147                0
# 3         14.067      3.71                0
# 4         14.067     2.906                0
# ...          ...       ...              ...
# 2700      10.806     1.186              201
# 2701      10.806     1.187              201
# 2702      10.806     2.224              201
# 2703      10.806     3.945              201
# 2704      10.806     2.347              201
#
# [2705 rows x 3 columns]

# %%
import pickle
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
# Build the regression model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    tf.keras.layers.Dense(8, activation='relu'),

    tf.keras.layers.Dense(1)
])

# %%
X_test
# Out:
#       month_cons inventory  encoded_product
# 1106      10.290     3.368              248
# 439       10.217     3.863               91
# 801       11.781     2.135              180
# 296       14.499     1.679               63
# 1718      13.525     2.502              385
# ...          ...       ...              ...
# 1190      14.638     3.287              266
# 2369      13.011     2.113              526
# 2543      14.642     2.175              112
# 1904      10.684     2.241              423
# 445       12.599     1.426               93
#
# [541 rows x 3 columns]

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train_scaled, y_train, epochs=100, batch_size=16, verbose=0)

# Get predictions on new data
y_pred = model.predict(X_test_scaled)

# Print the predictions
print(y_pred)
# Out:
# 17/17 [==============================] - 0s 1ms/step
# [[2.6735332]
#  [2.443585 ]
#  [3.70056  ]
#  [4.8888817]
#  [4.1919303]
#  [5.03526  ]
#  [4.6764073]
#  [4.3478746]
#  [2.1206517]
#  [2.127667 ]
#  [3.5362606]
#  [1.9864107]
#  [2.220556 ]
#  [4.8189716]
#  [4.096218 ]
#  [2.830781 ]
#  [4.390974 ]
#  [3.3492575]
#  [3.3701003]
#  [2.7488334]
#  [4.4266796]
#  [2.5760422]
#  [3.4634395]
#  [2.9656315]
#  [3.1626186]
#  [3.9318075]
#  [2.8639607]
#  [4.359743 ]
#  [2.7988799]
#  [3.7212632]
#  [4.1648803]
#  [1.9445391]
#  [3.3726456]
#  [4.574282 ]
#  [4.772997 ]
#  [4.2513986]
#  [3.1033583]
#  [4.6596675]
#  [4.734783 ]
#  [2.770053 ]
#  [1.8586576]
#  [2.454115 ]
#  [1.9888206]
#  [4.7864165]
#  [3.2735643]
#  [4.213213 ]
#  [3.8226414]
#  [4.0003915]
#  [2.3028893]
#  [3.048139 ]
#  [1.9524907]
#  [2.5159876]
#  [3.2586777]
#  [4.3689246]
#  [4.3549123]
#  [4.2435713]
#  [3.495049 ]
#  [4.71939  ]
#  [3.1375346]
#  [4.3599863]
#  [2.080711 ]
#  [2.9233975]
#  [3.1456556]
#  [2.7369986]
#  [5.0751624]
#  [2.3628201]
#  [4.5750875]
#  [4.6529207]
#  [3.8813562]
#  [4.417041 ]
#  [3.80193  ]
#  [2.8113842]
#  [2.2070727]
#  [3.7883172]
#  [4.757515 ]
#  [2.8448637]
#  [2.6743972]
#  [4.429406 ]
#  [2.0153744]
#  [2.3895319]
#  [3.190574 ]
#  [1.8316969]
#  [3.0387974]
#  [4.68886  ]
#  [2.8058925]
#  [2.1547563]
#  [3.3489516]
#  [4.2742257]
#  [3.6342883]
#  [4.288974 ]
#  [4.6304975]
#  [2.761238 ]
#  [4.140368 ]
#  [3.8968277]
#  [2.1556432]
#  [3.3460917]
#  [2.8424494]
#  [4.6056204]
#  [4.385617 ]
#  [3.5825334]
#  [3.5622134]
#  [3.7865849]
#  [3.2985158]
#  [4.1511   ]
#  [4.681081 ]
#  [2.054117 ]
#  [2.4181595]
#  [3.6706963]
#  [3.034336 ]
#  [1.843011 ]
#  [4.045523 ]
#  [4.77668  ]
#  [4.2448764]
#  [4.038593 ]
#  [4.1058264]
#  [3.140834 ]
#  [2.0699904]
#  [2.7137365]
#  [2.0549634]
#  [4.8207893]
#  [4.2709217]
#  [2.1002393]
#  [3.0891943]
#  [3.1527293]
#  [4.019338 ]
#  [3.8168352]
#  [1.8445395]
#  [4.0639567]
#  [3.635591 ]
#  [4.506342 ]
#  [3.6830125]
#  [3.4331708]
#  [2.9354143]
#  [4.7743564]
#  [4.6889486]
#  [3.7151115]
#  [4.063769 ]
#  [2.5033247]
#  [4.1469274]
#  [4.6380115]
#  [4.7774243]
#  [4.6060343]
#  [3.977354 ]
#  [2.634174 ]
#  [3.91113  ]
#  [4.086675 ]
#  [4.032755 ]
#  [2.240674 ]
#  [3.110168 ]
#  [4.551669 ]
#  [3.2511091]
#  [4.7218513]
#  [3.130176 ]
#  [3.555336 ]
#  [2.8236303]
#  [4.5523105]
#  [4.47283  ]
#  [2.9928734]
#  [2.4591913]
#  [3.5840514]
#  [3.6936421]
#  [3.5763478]
#  [4.1565666]
#  [4.315348 ]
#  [2.4778366]
#  [4.5272727]
#  [3.90096  ]
#  [1.8614925]
#  [3.5612953]
#  [4.220599 ]
#  [4.369554 ]
#  [4.271806 ]
#  [3.5918026]
#  [4.130221 ]
#  [2.5106752]
#  [4.6137033]
#  [3.7917247]
#  [2.6907716]
#  [2.232643 ]
#  [4.520523 ]
#  [3.4882061]
#  [3.1993122]
#  [3.9258113]
#  [1.8617629]
#  [4.6802135]
#  [4.569592 ]
#  [5.0609818]
#  [2.732895 ]
#  [3.1926131]
#  [3.5938482]
#  [4.2456865]
#  [2.233461 ]
#  [3.3671174]
#  [4.929788 ]
#  [4.3109927]
#  [3.0142448]
#  [2.7851732]
#  [2.6687212]
#  [3.0726538]
#  [1.9053707]
#  [2.6623995]
#  [1.8835446]
#  [3.9643779]
#  [3.3915935]
#  [2.7881174]
#  [3.3356805]
#  [4.147804 ]
#  [4.803918 ]
#  [3.0380416]
#  [3.9296196]
#  [4.933243 ]
#  [3.4856226]
#  [4.4582844]
#  [2.2285485]
#  [3.171879 ]
#  [2.3150835]
#  [3.8392537]
#  [3.9394655]
#  [4.1225915]
#  [2.5667777]
#  [4.367545 ]
#  [4.517236 ]
#  [4.3236856]
#  [2.5982327]
#  [2.4239783]
#  [3.5513384]
#  [3.2831743]
#  [2.7327552]
#  [4.214375 ]
#  [4.609914 ]
#  [4.478343 ]
#  [2.6537504]
#  [2.9811172]
#  [2.6217837]
#  [2.7413228]
#  [3.8408937]
#  [3.2525582]
#  [4.60988  ]
#  [3.7165418]
#  [2.9731324]
#  [1.812358 ]
#  [4.518282 ]
#  [4.1712832]
#  [3.3239903]
#  [2.7830105]
#  [3.2460387]
#  [4.0131903]
#  [2.6533227]
#  [2.75246  ]
#  [4.9252887]
#  [3.597462 ]
#  [3.8829823]
#  [3.458284 ]
#  [4.470499 ]
#  [2.9342856]
#  [2.768866 ]
#  [4.5185723]
#  [1.8745683]
#  [3.027903 ]
#  [2.4611545]
#  [2.21264  ]
#  [3.5411122]
#  [2.0593436]
#  [4.301808 ]
#  [4.5492344]
#  [2.6990223]
#  [4.1481056]
#  [4.6383867]
#  [3.0993705]
#  [3.3674593]
#  [4.740833 ]
#  [4.5446396]
#  [2.9258199]
#  [3.6737866]
#  [2.291473 ]
#  [4.930351 ]
#  [3.2752674]
#  [5.070591 ]
#  [2.2026498]
#  [4.2576203]
#  [2.4159594]
#  [4.0866866]
#  [3.6565924]
#  [3.4621096]
#  [2.9646616]
#  [2.8471775]
#  [3.022467 ]
#  [2.5800762]
#  [2.7741952]
#  [3.699648 ]
#  [3.3764338]
#  [3.295582 ]
#  [1.8304197]
#  [3.0389276]
#  [4.0812097]
#  [4.268282 ]
#  [2.4182172]
#  [3.3569539]
#  [2.9148107]
#  [4.0976353]
#  [2.8539906]
#  [4.2108593]
#  [3.7244267]
#  [3.2480044]
#  [3.7338943]
#  [4.5228567]
#  [3.6339524]
#  [4.7531986]
#  [3.8699944]
#  [3.4544206]
#  [3.3998444]
#  [2.512178 ]
#  [4.349589 ]
#  [3.2781649]
#  [3.3356376]
#  [3.8969693]
#  [3.8516335]
#  [4.8883824]
#  [3.2022238]
#  [2.8267365]
#  [4.5178895]
#  [4.2238126]
#  [2.6542592]
#  [3.8501987]
#  [3.6081543]
#  [4.4335613]
#  [5.011176 ]
#  [3.1095512]
#  [2.0968108]
#  [2.7819738]
#  [3.3356104]
#  [2.759592 ]
#  [3.9680967]
#  [4.157944 ]
#  [3.7928407]
#  [3.0909967]
#  [3.638691 ]
#  [4.097177 ]
#  [2.6786823]
#  [4.819808 ]
#  [5.029167 ]
#  [2.5236835]
#  [4.457611 ]
#  [4.320263 ]
#  [4.394779 ]
#  [4.031373 ]
#  [4.659856 ]
#  [3.942245 ]
#  [4.2963095]
#  [3.8830256]
#  [4.0309854]
#  [2.450479 ]
#  [4.2465696]
#  [2.368033 ]
#  [4.773597 ]
#  [3.0706787]
#  [4.0815454]
#  [1.9340264]
#  [4.624113 ]
#  [3.3428268]
#  [2.54214  ]
#  [3.122847 ]
#  [3.9863408]
#  [3.8520167]
#  [3.8158123]
#  [2.5901089]
#  [3.7598972]
#  [2.6237872]
#  [3.702636 ]
#  [3.7278533]
#  [4.227711 ]
#  [5.1138735]
#  [3.718678 ]
#  [2.755919 ]
#  [2.7848372]
#  [2.8550677]
#  [3.9110568]
#  [3.561499 ]
#  [3.638685 ]
#  [2.3397758]
#  [3.2808862]
#  [2.9279132]
#  [3.7491293]
#  [4.8204165]
#  [2.4072714]
#  [4.653046 ]
#  [2.686181 ]
#  [2.876647 ]
#  [3.8645248]
#  [2.0057425]
#  [3.432675 ]
#  [3.387106 ]
#  [2.6903753]
#  [1.7876006]
#  [4.2416573]
#  [2.7425463]
#  [2.3685675]
#  [3.0905113]
#  [5.173327 ]
#  [3.868338 ]
#  [4.4254293]
#  [2.4281769]
#  [4.137991 ]
#  [3.776706 ]
#  [3.6633039]
#  [2.0585432]
#  [3.6327934]
#  [4.111454 ]
#  [2.077948 ]
#  [4.1378417]
#  [3.857709 ]
#  [3.4107466]
#  [4.4783587]
#  [3.8236709]
#  [1.916546 ]
#  [3.7024858]
#  [4.3031497]
#  [3.5647185]
#  [1.8307884]
#  [2.5248406]
#  [2.9212837]
#  [3.9653482]
#  [4.463895 ]
#  [3.468676 ]
#  [4.1159177]
#  [2.787961 ]
#  [4.461779 ]
#  [2.2113554]
#  [3.319674 ]
#  [3.886904 ]
#  [4.038839 ]
#  [3.2417817]
#  [4.10153  ]
#  [3.6064744]
#  [4.555046 ]
#  [3.1868825]
#  [3.5909734]
#  [2.883864 ]
#  [4.952573 ]
#  [3.8705022]
#  [2.9331684]
#  [4.1563168]
#  [3.2108593]
#  [2.3447332]
#  [4.6102366]
#  [4.0174713]
#  [3.7377613]
#  [2.7186284]
#  [2.4030163]
#  [3.0751228]
#  [4.432753 ]
#  [3.0243144]
#  [3.3240662]
#  [2.9464507]
#  [2.4036427]
#  [3.7528284]
#  [4.0628915]
#  [3.7431903]
#  [4.0418854]
#  [3.5026956]
#  [3.636325 ]
#  [3.3117137]
#  [4.2596087]
#  [4.3576794]
#  [3.3264778]
#  [2.5913794]
#  [2.1124349]
#  [3.166414 ]
#  [2.2971363]
#  [4.0676336]
#  [4.3499937]
#  [2.7420516]
#  [2.3180714]
#  [4.219277 ]
#  [2.8349602]
#  [3.37059  ]
#  [3.2932293]
#  [4.3353424]
#  [2.4943957]
#  [2.4553504]
#  [4.881344 ]
#  [2.6807666]
#  [3.91288  ]
#  [4.9407606]
#  [3.4063287]
#  [4.253369 ]
#  [3.8730102]
#  [4.125053 ]
#  [3.7802932]
#  [4.837263 ]
#  [2.877316 ]
#  [1.9927478]
#  [3.810498 ]
#  [4.907318 ]
#  [3.6594985]
#  [4.8219175]
#  [4.7364492]
#  [2.7900672]
#  [4.007175 ]
#  [3.724899 ]
#  [3.2272987]
#  [2.4944205]
#  [4.927912 ]
#  [1.905661 ]
#  [3.9602263]
#  [4.683922 ]
#  [4.275857 ]
#  [2.9669924]
#  [2.3812513]
#  [3.760852 ]
#  [4.251644 ]
#  [4.7676287]
#  [3.6070378]
#  [2.236238 ]
#  [4.1825476]
#  [2.7075567]
#  [3.2528596]
#  [4.1342454]
#  [3.131258 ]
#  [4.466746 ]
#  [2.1627345]
#  [2.3203294]
#  [3.5920017]
#  [4.0518003]
#  [3.4283412]
#  [1.7900177]
#  [4.7546763]
#  [2.4068694]
#  [2.846819 ]
#  [2.091577 ]
#  [2.6103384]
#  [4.540981 ]
#  [3.2209125]
#  [4.239814 ]
#  [4.296141 ]
#  [3.5182123]
#  [4.4314413]
#  [4.1366787]
#  [4.772676 ]
#  [3.290484 ]
#  [4.266397 ]]

# %%
print(y_test
      )
# Out:
# 1106    2.533
# 439     2.586
# 801     3.401
# 296     4.792
# 1718    4.084
#         ...
# 1190    4.664
# 2369    4.672
# 2543    4.735
# 1904    3.474
# 445     4.664
# Name: rec_qte, Length: 541, dtype: float64

# %%
print(y_pred)
# Out:
# [[2.6735332]
#  [2.443585 ]
#  [3.70056  ]
#  [4.8888817]
#  [4.1919303]
#  [5.03526  ]
#  [4.6764073]
#  [4.3478746]
#  [2.1206517]
#  [2.127667 ]
#  [3.5362606]
#  [1.9864107]
#  [2.220556 ]
#  [4.8189716]
#  [4.096218 ]
#  [2.830781 ]
#  [4.390974 ]
#  [3.3492575]
#  [3.3701003]
#  [2.7488334]
#  [4.4266796]
#  [2.5760422]
#  [3.4634395]
#  [2.9656315]
#  [3.1626186]
#  [3.9318075]
#  [2.8639607]
#  [4.359743 ]
#  [2.7988799]
#  [3.7212632]
#  [4.1648803]
#  [1.9445391]
#  [3.3726456]
#  [4.574282 ]
#  [4.772997 ]
#  [4.2513986]
#  [3.1033583]
#  [4.6596675]
#  [4.734783 ]
#  [2.770053 ]
#  [1.8586576]
#  [2.454115 ]
#  [1.9888206]
#  [4.7864165]
#  [3.2735643]
#  [4.213213 ]
#  [3.8226414]
#  [4.0003915]
#  [2.3028893]
#  [3.048139 ]
#  [1.9524907]
#  [2.5159876]
#  [3.2586777]
#  [4.3689246]
#  [4.3549123]
#  [4.2435713]
#  [3.495049 ]
#  [4.71939  ]
#  [3.1375346]
#  [4.3599863]
#  [2.080711 ]
#  [2.9233975]
#  [3.1456556]
#  [2.7369986]
#  [5.0751624]
#  [2.3628201]
#  [4.5750875]
#  [4.6529207]
#  [3.8813562]
#  [4.417041 ]
#  [3.80193  ]
#  [2.8113842]
#  [2.2070727]
#  [3.7883172]
#  [4.757515 ]
#  [2.8448637]
#  [2.6743972]
#  [4.429406 ]
#  [2.0153744]
#  [2.3895319]
#  [3.190574 ]
#  [1.8316969]
#  [3.0387974]
#  [4.68886  ]
#  [2.8058925]
#  [2.1547563]
#  [3.3489516]
#  [4.2742257]
#  [3.6342883]
#  [4.288974 ]
#  [4.6304975]
#  [2.761238 ]
#  [4.140368 ]
#  [3.8968277]
#  [2.1556432]
#  [3.3460917]
#  [2.8424494]
#  [4.6056204]
#  [4.385617 ]
#  [3.5825334]
#  [3.5622134]
#  [3.7865849]
#  [3.2985158]
#  [4.1511   ]
#  [4.681081 ]
#  [2.054117 ]
#  [2.4181595]
#  [3.6706963]
#  [3.034336 ]
#  [1.843011 ]
#  [4.045523 ]
#  [4.77668  ]
#  [4.2448764]
#  [4.038593 ]
#  [4.1058264]
#  [3.140834 ]
#  [2.0699904]
#  [2.7137365]
#  [2.0549634]
#  [4.8207893]
#  [4.2709217]
#  [2.1002393]
#  [3.0891943]
#  [3.1527293]
#  [4.019338 ]
#  [3.8168352]
#  [1.8445395]
#  [4.0639567]
#  [3.635591 ]
#  [4.506342 ]
#  [3.6830125]
#  [3.4331708]
#  [2.9354143]
#  [4.7743564]
#  [4.6889486]
#  [3.7151115]
#  [4.063769 ]
#  [2.5033247]
#  [4.1469274]
#  [4.6380115]
#  [4.7774243]
#  [4.6060343]
#  [3.977354 ]
#  [2.634174 ]
#  [3.91113  ]
#  [4.086675 ]
#  [4.032755 ]
#  [2.240674 ]
#  [3.110168 ]
#  [4.551669 ]
#  [3.2511091]
#  [4.7218513]
#  [3.130176 ]
#  [3.555336 ]
#  [2.8236303]
#  [4.5523105]
#  [4.47283  ]
#  [2.9928734]
#  [2.4591913]
#  [3.5840514]
#  [3.6936421]
#  [3.5763478]
#  [4.1565666]
#  [4.315348 ]
#  [2.4778366]
#  [4.5272727]
#  [3.90096  ]
#  [1.8614925]
#  [3.5612953]
#  [4.220599 ]
#  [4.369554 ]
#  [4.271806 ]
#  [3.5918026]
#  [4.130221 ]
#  [2.5106752]
#  [4.6137033]
#  [3.7917247]
#  [2.6907716]
#  [2.232643 ]
#  [4.520523 ]
#  [3.4882061]
#  [3.1993122]
#  [3.9258113]
#  [1.8617629]
#  [4.6802135]
#  [4.569592 ]
#  [5.0609818]
#  [2.732895 ]
#  [3.1926131]
#  [3.5938482]
#  [4.2456865]
#  [2.233461 ]
#  [3.3671174]
#  [4.929788 ]
#  [4.3109927]
#  [3.0142448]
#  [2.7851732]
#  [2.6687212]
#  [3.0726538]
#  [1.9053707]
#  [2.6623995]
#  [1.8835446]
#  [3.9643779]
#  [3.3915935]
#  [2.7881174]
#  [3.3356805]
#  [4.147804 ]
#  [4.803918 ]
#  [3.0380416]
#  [3.9296196]
#  [4.933243 ]
#  [3.4856226]
#  [4.4582844]
#  [2.2285485]
#  [3.171879 ]
#  [2.3150835]
#  [3.8392537]
#  [3.9394655]
#  [4.1225915]
#  [2.5667777]
#  [4.367545 ]
#  [4.517236 ]
#  [4.3236856]
#  [2.5982327]
#  [2.4239783]
#  [3.5513384]
#  [3.2831743]
#  [2.7327552]
#  [4.214375 ]
#  [4.609914 ]
#  [4.478343 ]
#  [2.6537504]
#  [2.9811172]
#  [2.6217837]
#  [2.7413228]
#  [3.8408937]
#  [3.2525582]
#  [4.60988  ]
#  [3.7165418]
#  [2.9731324]
#  [1.812358 ]
#  [4.518282 ]
#  [4.1712832]
#  [3.3239903]
#  [2.7830105]
#  [3.2460387]
#  [4.0131903]
#  [2.6533227]
#  [2.75246  ]
#  [4.9252887]
#  [3.597462 ]
#  [3.8829823]
#  [3.458284 ]
#  [4.470499 ]
#  [2.9342856]
#  [2.768866 ]
#  [4.5185723]
#  [1.8745683]
#  [3.027903 ]
#  [2.4611545]
#  [2.21264  ]
#  [3.5411122]
#  [2.0593436]
#  [4.301808 ]
#  [4.5492344]
#  [2.6990223]
#  [4.1481056]
#  [4.6383867]
#  [3.0993705]
#  [3.3674593]
#  [4.740833 ]
#  [4.5446396]
#  [2.9258199]
#  [3.6737866]
#  [2.291473 ]
#  [4.930351 ]
#  [3.2752674]
#  [5.070591 ]
#  [2.2026498]
#  [4.2576203]
#  [2.4159594]
#  [4.0866866]
#  [3.6565924]
#  [3.4621096]
#  [2.9646616]
#  [2.8471775]
#  [3.022467 ]
#  [2.5800762]
#  [2.7741952]
#  [3.699648 ]
#  [3.3764338]
#  [3.295582 ]
#  [1.8304197]
#  [3.0389276]
#  [4.0812097]
#  [4.268282 ]
#  [2.4182172]
#  [3.3569539]
#  [2.9148107]
#  [4.0976353]
#  [2.8539906]
#  [4.2108593]
#  [3.7244267]
#  [3.2480044]
#  [3.7338943]
#  [4.5228567]
#  [3.6339524]
#  [4.7531986]
#  [3.8699944]
#  [3.4544206]
#  [3.3998444]
#  [2.512178 ]
#  [4.349589 ]
#  [3.2781649]
#  [3.3356376]
#  [3.8969693]
#  [3.8516335]
#  [4.8883824]
#  [3.2022238]
#  [2.8267365]
#  [4.5178895]
#  [4.2238126]
#  [2.6542592]
#  [3.8501987]
#  [3.6081543]
#  [4.4335613]
#  [5.011176 ]
#  [3.1095512]
#  [2.0968108]
#  [2.7819738]
#  [3.3356104]
#  [2.759592 ]
#  [3.9680967]
#  [4.157944 ]
#  [3.7928407]
#  [3.0909967]
#  [3.638691 ]
#  [4.097177 ]
#  [2.6786823]
#  [4.819808 ]
#  [5.029167 ]
#  [2.5236835]
#  [4.457611 ]
#  [4.320263 ]
#  [4.394779 ]
#  [4.031373 ]
#  [4.659856 ]
#  [3.942245 ]
#  [4.2963095]
#  [3.8830256]
#  [4.0309854]
#  [2.450479 ]
#  [4.2465696]
#  [2.368033 ]
#  [4.773597 ]
#  [3.0706787]
#  [4.0815454]
#  [1.9340264]
#  [4.624113 ]
#  [3.3428268]
#  [2.54214  ]
#  [3.122847 ]
#  [3.9863408]
#  [3.8520167]
#  [3.8158123]
#  [2.5901089]
#  [3.7598972]
#  [2.6237872]
#  [3.702636 ]
#  [3.7278533]
#  [4.227711 ]
#  [5.1138735]
#  [3.718678 ]
#  [2.755919 ]
#  [2.7848372]
#  [2.8550677]
#  [3.9110568]
#  [3.561499 ]
#  [3.638685 ]
#  [2.3397758]
#  [3.2808862]
#  [2.9279132]
#  [3.7491293]
#  [4.8204165]
#  [2.4072714]
#  [4.653046 ]
#  [2.686181 ]
#  [2.876647 ]
#  [3.8645248]
#  [2.0057425]
#  [3.432675 ]
#  [3.387106 ]
#  [2.6903753]
#  [1.7876006]
#  [4.2416573]
#  [2.7425463]
#  [2.3685675]
#  [3.0905113]
#  [5.173327 ]
#  [3.868338 ]
#  [4.4254293]
#  [2.4281769]
#  [4.137991 ]
#  [3.776706 ]
#  [3.6633039]
#  [2.0585432]
#  [3.6327934]
#  [4.111454 ]
#  [2.077948 ]
#  [4.1378417]
#  [3.857709 ]
#  [3.4107466]
#  [4.4783587]
#  [3.8236709]
#  [1.916546 ]
#  [3.7024858]
#  [4.3031497]
#  [3.5647185]
#  [1.8307884]
#  [2.5248406]
#  [2.9212837]
#  [3.9653482]
#  [4.463895 ]
#  [3.468676 ]
#  [4.1159177]
#  [2.787961 ]
#  [4.461779 ]
#  [2.2113554]
#  [3.319674 ]
#  [3.886904 ]
#  [4.038839 ]
#  [3.2417817]
#  [4.10153  ]
#  [3.6064744]
#  [4.555046 ]
#  [3.1868825]
#  [3.5909734]
#  [2.883864 ]
#  [4.952573 ]
#  [3.8705022]
#  [2.9331684]
#  [4.1563168]
#  [3.2108593]
#  [2.3447332]
#  [4.6102366]
#  [4.0174713]
#  [3.7377613]
#  [2.7186284]
#  [2.4030163]
#  [3.0751228]
#  [4.432753 ]
#  [3.0243144]
#  [3.3240662]
#  [2.9464507]
#  [2.4036427]
#  [3.7528284]
#  [4.0628915]
#  [3.7431903]
#  [4.0418854]
#  [3.5026956]
#  [3.636325 ]
#  [3.3117137]
#  [4.2596087]
#  [4.3576794]
#  [3.3264778]
#  [2.5913794]
#  [2.1124349]
#  [3.166414 ]
#  [2.2971363]
#  [4.0676336]
#  [4.3499937]
#  [2.7420516]
#  [2.3180714]
#  [4.219277 ]
#  [2.8349602]
#  [3.37059  ]
#  [3.2932293]
#  [4.3353424]
#  [2.4943957]
#  [2.4553504]
#  [4.881344 ]
#  [2.6807666]
#  [3.91288  ]
#  [4.9407606]
#  [3.4063287]
#  [4.253369 ]
#  [3.8730102]
#  [4.125053 ]
#  [3.7802932]
#  [4.837263 ]
#  [2.877316 ]
#  [1.9927478]
#  [3.810498 ]
#  [4.907318 ]
#  [3.6594985]
#  [4.8219175]
#  [4.7364492]
#  [2.7900672]
#  [4.007175 ]
#  [3.724899 ]
#  [3.2272987]
#  [2.4944205]
#  [4.927912 ]
#  [1.905661 ]
#  [3.9602263]
#  [4.683922 ]
#  [4.275857 ]
#  [2.9669924]
#  [2.3812513]
#  [3.760852 ]
#  [4.251644 ]
#  [4.7676287]
#  [3.6070378]
#  [2.236238 ]
#  [4.1825476]
#  [2.7075567]
#  [3.2528596]
#  [4.1342454]
#  [3.131258 ]
#  [4.466746 ]
#  [2.1627345]
#  [2.3203294]
#  [3.5920017]
#  [4.0518003]
#  [3.4283412]
#  [1.7900177]
#  [4.7546763]
#  [2.4068694]
#  [2.846819 ]
#  [2.091577 ]
#  [2.6103384]
#  [4.540981 ]
#  [3.2209125]
#  [4.239814 ]
#  [4.296141 ]
#  [3.5182123]
#  [4.4314413]
#  [4.1366787]
#  [4.772676 ]
#  [3.290484 ]
#  [4.266397 ]]

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
mse
# Out:
# 0.07660574371216412

# %%
r2
# Out:
# 0.9107071851776287

# %%
y_test
# Out:
# 1106    2.533
# 439     2.586
# 801     3.401
# 296     4.792
# 1718    4.084
#         ...
# 1190    4.664
# 2369    4.672
# 2543    4.735
# 1904    3.474
# 445     4.664
# Name: rec_qte, Length: 541, dtype: float64

# %%
ww=y_test.values

# %%
ww
# Out:
# array([2.533, 2.586, 3.401, 4.792, 4.084, 5.467, 4.817, 4.362, 2.001,
#        1.876, 3.222, 2.204, 2.052, 4.646, 4.44 , 3.077, 4.717, 2.955,
#        3.805, 2.872, 5.072, 2.595, 3.122, 3.062, 3.498, 4.364, 3.057,
#        3.925, 2.745, 3.614, 3.875, 1.98 , 3.66 , 5.003, 4.809, 3.858,
#        3.197, 4.172, 4.43 , 3.034, 1.65 , 2.801, 1.77 , 5.174, 3.487,
#        4.485, 4.289, 4.154, 2.169, 3.432, 2.016, 2.378, 3.191, 3.972,
#        3.853, 3.812, 3.559, 4.612, 3.457, 3.939, 1.809, 3.126, 2.916,
#        3.105, 4.67 , 2.487, 4.783, 4.139, 4.08 , 4.787, 3.575, 2.693,
#        2.138, 3.534, 5.199, 2.654, 2.513, 4.257, 1.877, 2.565, 2.826,
#        1.738, 3.076, 4.194, 2.75 , 1.996, 3.063, 4.126, 3.764, 4.557,
#        4.878, 3.071, 4.657, 3.968, 2.302, 2.981, 2.495, 4.294, 4.218,
#        3.48 , 3.569, 3.82 , 3.313, 4.383, 4.776, 2.003, 2.39 , 3.628,
#        2.769, 1.836, 3.911, 5.459, 4.171, 3.916, 3.838, 2.791, 2.235,
#        2.927, 2.118, 4.363, 4.179, 1.952, 3.102, 3.274, 4.574, 4.092,
#        1.633, 4.083, 3.452, 4.329, 3.559, 3.277, 2.756, 4.915, 5.227,
#        3.703, 4.394, 2.748, 4.223, 4.315, 4.938, 4.804, 4.4  , 2.363,
#        3.426, 3.757, 3.772, 2.275, 3.493, 3.991, 3.275, 4.692, 2.815,
#        3.149, 3.046, 4.526, 4.331, 2.771, 2.247, 3.77 , 3.327, 3.344,
#        3.954, 4.914, 2.446, 4.495, 3.841, 1.576, 3.201, 4.252, 4.339,
#        4.39 , 3.886, 3.58 , 2.567, 4.418, 3.42 , 2.869, 1.962, 4.222,
#        3.397, 3.192, 4.385, 1.96 , 4.653, 4.79 , 5.462, 3.056, 2.918,
#        3.397, 4.196, 2.16 , 3.561, 4.81 , 4.018, 2.668, 2.93 , 2.692,
#        3.234, 1.842, 2.434, 1.781, 4.036, 3.299, 3.143, 3.828, 4.003,
#        5.321, 3.44 , 4.282, 4.544, 3.828, 4.336, 1.927, 2.881, 2.386,
#        3.763, 4.017, 4.056, 2.437, 3.744, 4.685, 3.93 , 2.62 , 2.441,
#        3.211, 3.37 , 2.808, 4.222, 4.303, 4.67 , 2.369, 2.653, 2.824,
#        2.817, 3.467, 3.583, 4.826, 3.46 , 3.216, 1.851, 4.125, 4.304,
#        3.151, 2.869, 2.943, 4.156, 2.716, 2.441, 4.976, 4.081, 3.839,
#        3.592, 4.42 , 3.302, 3.024, 4.967, 1.779, 2.751, 2.49 , 2.023,
#        3.628, 1.885, 4.41 , 4.185, 2.422, 3.848, 5.143, 3.088, 3.08 ,
#        5.15 , 4.614, 2.986, 3.786, 2.31 , 5.634, 2.901, 5.05 , 2.118,
#        3.714, 2.324, 3.879, 3.384, 3.097, 2.975, 2.474, 2.847, 2.373,
#        2.555, 3.961, 3.816, 2.888, 1.889, 2.829, 3.689, 4.11 , 2.558,
#        3.761, 3.027, 4.21 , 2.672, 4.66 , 3.519, 3.245, 3.506, 4.976,
#        3.249, 4.344, 3.505, 3.282, 3.237, 2.182, 4.462, 3.346, 3.373,
#        3.719, 3.338, 5.512, 3.525, 2.782, 4.175, 3.914, 2.426, 3.762,
#        4.068, 4.585, 5.239, 2.763, 2.098, 3.085, 3.321, 2.384, 3.847,
#        3.776, 3.249, 3.008, 3.46 , 4.38 , 2.523, 5.146, 5.163, 2.312,
#        4.015, 4.704, 4.935, 4.605, 4.699, 3.823, 4.437, 4.229, 4.287,
#        2.576, 4.254, 2.34 , 4.639, 2.887, 3.978, 1.777, 4.769, 3.34 ,
#        2.237, 2.976, 4.385, 4.078, 3.303, 2.984, 4.016, 2.324, 3.4  ,
#        3.403, 4.253, 5.264, 3.462, 2.463, 2.855, 3.232, 3.659, 3.549,
#        3.613, 2.275, 3.261, 2.59 , 3.296, 5.173, 2.506, 4.499, 2.941,
#        2.747, 4.37 , 1.862, 3.193, 3.068, 2.721, 1.743, 4.192, 2.742,
#        2.286, 2.981, 5.657, 4.278, 4.73 , 2.458, 4.457, 4.316, 3.684,
#        2.162, 3.237, 4.399, 2.014, 4.026, 4.01 , 3.295, 4.94 , 4.089,
#        1.996, 3.604, 4.502, 3.813, 1.884, 2.69 , 3.049, 3.997, 4.274,
#        3.449, 4.19 , 3.053, 4.479, 2.068, 3.035, 3.802, 4.666, 3.347,
#        4.663, 3.743, 5.065, 3.491, 3.273, 2.617, 5.111, 3.488, 3.167,
#        3.655, 3.327, 2.414, 4.224, 4.169, 3.867, 2.427, 2.362, 2.966,
#        4.421, 3.223, 3.024, 3.111, 2.638, 3.708, 4.522, 3.604, 3.804,
#        3.465, 3.212, 2.985, 4.049, 4.747, 3.036, 2.34 , 2.015, 3.063,
#        2.454, 4.244, 4.487, 2.825, 2.499, 4.739, 2.743, 3.243, 3.172,
#        3.792, 2.595, 2.567, 5.274, 2.356, 4.253, 5.684, 3.6  , 4.046,
#        3.429, 4.052, 3.906, 4.506, 3.253, 1.946, 3.487, 4.698, 3.605,
#        5.132, 4.27 , 2.575, 4.416, 3.728, 3.349, 2.315, 5.458, 1.692,
#        4.324, 4.682, 3.689, 2.742, 2.202, 3.413, 4.403, 4.287, 3.462,
#        2.056, 3.871, 2.408, 3.024, 4.417, 3.074, 5.049, 1.976, 2.509,
#        4.033, 4.421, 3.555, 1.675, 4.181, 2.545, 2.817, 2.074, 2.333,
#        5.184, 3.363, 3.903, 4.463, 3.173, 4.664, 4.672, 4.735, 3.474,
#        4.664])

# %%
ww[0]
# Out:
# 2.533

# %%
l=[]
for i in range(len(ww)):
  l.append(abs(ww[i]-y_pred[i][0]))
print(max(l))
# Out:
# 0.7432393875122072

# %%
print(ww[4])
print(y_pred[4][0])
# Out:
# 4.084
# 4.1919303

# %%
X_test
# Out:
#       month_cons inventory  encoded_product
# 1106      10.290     3.368              248
# 439       10.217     3.863               91
# 801       11.781     2.135              180
# 296       14.499     1.679               63
# 1718      13.525     2.502              385
# ...          ...       ...              ...
# 1190      14.638     3.287              266
# 2369      13.011     2.113              526
# 2543      14.642     2.175              112
# 1904      10.684     2.241              423
# 445       12.599     1.426               93
#
# [541 rows x 3 columns]

# %%
data
# Out:
#       month_cons inventory  rec_qte  encoded_product
# 0         14.067     3.188    4.215                0
# 1         14.067     1.691    5.030                0
# 2         14.067     3.147    3.800                0
# 3         14.067      3.71    3.732                0
# 4         14.067     2.906    4.069                0
# ...          ...       ...      ...              ...
# 2700      10.806     1.186    3.605              201
# 2701      10.806     1.187    3.332              201
# 2702      10.806     2.224    3.306              201
# 2703      10.806     3.945    2.578              201
# 2704      10.806     2.347    3.192              201
#
# [2705 rows x 4 columns]

# %%
data[data['encoded_product']==248]
# Out:
#       month_cons inventory  rec_qte  encoded_product
# 1105       10.29     2.352    2.998              248
# 1106       10.29     3.368    2.533              248
# 1107       10.29     3.459    2.716              248
# 1108       10.29     1.366    3.105              248
# 1109       10.29     2.137    3.113              248

# %%
row_1106 = data.loc[801]

# %%
row_1106
# Out:
# month_cons         11.781
# inventory           2.135
# rec_qte             3.401
# encoded_product       180
# Name: 801, dtype: object

# %% [markdown]
# product       Chicken Fajitas
#
# month_cons             10.217
# inventory               3.863
# rec_qte                 2.586

# %%
encoded_product = res.loc[res['product'] =="Light Sour Cream", 'encoded_product'].values[0]

# %%
encoded_product
# Out:
# 248

# %%
from keras import models
import numpy as np

def get_predictions( month_cons, inventory, product,model=model, scaler=scaler):

    encoded_product = res.loc[res['product'] == product, 'encoded_product'].values[0]
    input_data = np.array([[month_cons, inventory, encoded_product]])


    scaled_input_data = scaler.transform(input_data)


    predictions = model.predict(scaled_input_data)
    return predictions

prediction = get_predictions(10.217,3.863,"Chicken Fajitas")
print("Predicted rec_qte:", prediction[0][0])
# Out:
# 1/1 [==============================] - 0s 19ms/step
# Predicted rec_qte: 2.443585
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
y_test

# %%
import pickle

# %%
pickle.dump(model,open('_model.pkl','wb'))
pickle.dump(res,open('dta.pkl','wb'))

# %%
pickle.dump(scaler,open('scaler.pkl','wb'))
